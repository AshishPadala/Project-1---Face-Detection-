# %%
pip install opencv-python matplotlib
# Out:
# Requirement already satisfied: opencv-python in c:\users\ashis\anaconda3\lib\site-packages (4.8.0.74)
# Requirement already satisfied: matplotlib in c:\users\ashis\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\ashis\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ashis\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ashis\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ashis\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ashis\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ashis\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ashis\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ashis\anaconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\ashis\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt

# Load the pre-trained face detection classifier
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Load the image
image = cv2.imread('FACES-DB-Delta-Dental-Michigan-1.png')

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Perform face detection
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Draw rectangles around the detected faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Convert BGR image to RGB for plotting
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image with detected faces
plt.imshow(image_rgb)
plt.axis('off')
plt.show()
